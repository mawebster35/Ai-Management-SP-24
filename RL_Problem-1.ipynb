# %% [markdown]
# **Problem:** An un-actuated joint attaches a pole to a cart, which moves along a frictionless track. The pendulum starts moving, and the goal is to prevent it from falling over by moving the cart left and right.![Screenshot 2024-01-29 at 8.27.32 PM.png](data:image/png;base64,...)

# %%
# Installations
# !pip install gym
# !pip install gym[atari]
# !pip install swig
# !pip install box2d-py
# !pip install pyglet

# %%
# Importing necessary packages
from time import sleep
import gym
import random

# %%
# Initializing CartPole Environment
env = gym.make('CartPole-v1')

# %%
# Action Space
seed = 0
random.seed(seed)
env.seed(seed)
print(f'Action Space: {env.action_space}')

# %%
# Observation Space
print(f'Observation Space: {env.observation_space}')

# %% [markdown]
# # **Part A**

# %% [markdown]
# **Question:** Write a Python program that implements a policy of random movements to address the specified problem. Set the number of episodes to 10.

# %%
# Your code #

# %% [markdown]
# **Explanation:**

# %% [markdown]
# ## **Part B**

# %% [markdown]
# **Question:** Write a program in Python that adopts a non-random policy to solve the problem. (Num_of_episodes = 10)

# %%
# Your code #

# %% [markdown]
# **Explanation:**
